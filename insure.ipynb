# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70c978b9-e9e0-4075-a8a0-1f6103d5d822" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70c978b9-e9e0-4075-a8a0-1f6103d5d822">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
insurance_data = pd.read_csv("insurance.csv")
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
insurance_data.shape
# Out:
# (1338, 7)

# %%
insurance_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
insurance_data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.duplicated().any()
# Out:
# np.True_

# %%
insurance_data[insurance_data.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
insurance_data1 = insurance_data.drop_duplicates()

# %%
insurance_data1.shape
# Out:
# (1337, 7)

# %%
insurance_data1.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
insurance_data1.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
Numerical_columns = insurance_data1.select_dtypes(include = "number").columns.to_list()
print(Numerical_columns)

Categorical_columns = insurance_data1.select_dtypes(exclude='number').columns.to_list()
Categorical_columns
# Out:
# ['age', 'bmi', 'children', 'charges']
# ['sex', 'smoker', 'region']

# %%
insurance_data1.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance_data1.describe(exclude='number')
# Out:
#          sex smoker     region
# count   1337   1337       1337
# unique     2      2          4
# top     male     no  southeast
# freq     675   1063        364

# %%
insurance_data1['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
insurance_data1['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
insurance_data1['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
insurance_data1['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
insurance_data1['region'].nunique()
# Out:
# 4

# %%
insurance_data1['age'].plot(kind='hist')
plt.title('Age Distribution')
plt.show()

# %%
insurance_data1['bmi'].plot(kind='hist')
plt.title('BMI Distribution')
plt.show()

# %%
insurance_data1['children'].plot(kind='hist')
plt.title('No of Children')
plt.show()

# %%
insurance_data1['charges'].plot(kind='hist', color = 'pink')
plt.title('Charges')
plt.xlabel('Amount')
plt.show()

# %%
Categorical_columns
# Out:
# ['sex', 'smoker', 'region']

# %%
insurance_data1['sex'].value_counts().plot(kind='bar')
plt.title("Sex")
plt.show()

# %%
insurance_data1['smoker'].value_counts().plot(kind='bar')
plt.title("Smoke")
plt.show()

# %%
insurance_data1['region'].value_counts().plot(kind='pie')
plt.title('Region Distribution')
# Out:
# Text(0.5, 1.0, 'Region Distribution')

# %% [markdown]
# Scatter Plot

# %%
plt.scatter(data = insurance_data1 , x = 'age', y= 'charges')

# %%
plt.scatter(data = insurance_data1 , x = 'bmi', y= 'charges')

# %%
Numerical_columns
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
plt.scatter(data = insurance_data1 , x = 'age', y= 'charges')

# %% [markdown]
# Insurance for Smokers vs Non-Smokers

# %%
insurance_data1['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
sk = insurance_data1.groupby('smoker')['charges'].mean()
sk
# Out:
# smoker
# no      8440.660307
# yes    32050.231832
# Name: charges, dtype: float64

# %%
sk.plot(kind = 'bar')
plt.title('Comparision between cost incurred')
# Out:
# Text(0.5, 1.0, 'Comparision between cost incurred')

# %%
fk = insurance_data1.groupby('smoker')['charges'].sum()

fk.plot(kind = 'bar')
plt.title('Amount Spent by both')
# Out:
# Text(0.5, 1.0, 'Amount Spent by both')

# %%
Numerical_columns
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
Categorical_columns
# Out:
# ['sex', 'smoker', 'region']

# %%
ak = insurance_data1.groupby('sex')['age'].mean()
ak
# Out:
# sex
# female    39.503021
# male      38.946667
# Name: age, dtype: float64

# %%
mb = insurance_data1.groupby('sex')['bmi'].max()
mb
# Out:
# sex
# female    48.07
# male      53.13
# Name: bmi, dtype: float64

# %%
rk = insurance_data1.groupby('region')['bmi'].mean()
rk
# Out:
# region
# northeast    29.173503
# northwest    29.195494
# southeast    33.355989
# southwest    30.596615
# Name: bmi, dtype: float64

# %%
rk.plot(kind = 'bar')
plt.title('Region wise mean bmi')
# Out:
# Text(0.5, 1.0, 'Region wise mean bmi')

# %% [markdown]
# ML Model

# %%
insurance_data1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#label encoding to convert categorical variables

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
insurance_data1['sex'] = le.fit_transform(insurance_data1['sex'])
insurance_data1['smoker'] = le.fit_transform(insurance_data1['smoker'])
insurance_data1['region'] = le.fit_transform(insurance_data1['region'])
# Out:
# /tmp/ipython-input-1414544026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_data1['sex'] = le.fit_transform(insurance_data1['sex'])
# /tmp/ipython-input-1414544026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_data1['smoker'] = le.fit_transform(insurance_data1['smoker'])
# /tmp/ipython-input-1414544026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
insurance_data1.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
X = insurance_data1.drop(columns=['charges'],axis = 1)
Y = insurance_data1["charges"]

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test , Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42,shuffle=True)

print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
#       age  sex     bmi  children  smoker  region
# 1114   23    1  24.510         0       0       0
# 968    21    1  25.745         2       0       0
# 599    52    0  37.525         2       0       1
# 170    63    1  41.470         0       0       2
# 275    47    0  26.600         2       0       0
# ...   ...  ...     ...       ...     ...     ...
# 1096   51    0  34.960         2       1       0
# 1131   27    1  45.900         2       0       3
# 1295   20    1  22.000         1       0       3
# 861    38    0  28.000         3       0       3
# 1127   35    0  35.860         2       0       2
#
# [1069 rows x 6 columns]
#       age  sex     bmi  children  smoker  region
# 900    49    1  22.515         0       0       0
# 1064   29    0  25.600         4       0       3
# 1256   51    0  36.385         3       0       1
# 298    31    1  34.390         3       1       1
# 237    31    1  38.390         2       0       2
# ...   ...  ...     ...       ...     ...     ...
# ...

# %%
insurance_data1.shape
# Out:
# (1337, 7)

# %%
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (1069, 6) (268, 6)
# (1069,) (268,)

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
##Standardization

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
X['age'] = std_scaler.fit_transform(np.array(X['age']).reshape(-1,1))
X['bmi'] = std_scaler.fit_transform(np.array(X['bmi']).reshape(-1,1))
X['children'] = std_scaler.fit_transform(np.array(X['children']).reshape(-1,1))

# %%
X
# Out:
#            age  sex       bmi  children  smoker  region
# 0    -1.440418    0 -0.453160 -0.909234       1       3
# 1    -1.511647    1  0.509422 -0.079442       0       2
# 2    -0.799350    1  0.383155  1.580143       0       2
# 3    -0.443201    1 -1.305052 -0.909234       0       1
# 4    -0.514431    1 -0.292456 -0.909234       0       1
# ...        ...  ...       ...       ...     ...     ...
# 1333  0.767704    1  0.050269  1.580143       0       1
# 1334 -1.511647    0  0.206053 -0.909234       0       0
# 1335 -1.511647    0  1.014490 -0.909234       0       2
# 1336 -1.297958    0 -0.797524 -0.909234       0       3
# 1337  1.551231    0 -0.261299 -0.909234       1       1
#
# [1337 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score , cross_validate

# %%
result = cross_validate(lm,X,Y, cv =5 , return_train_score=True,scoring = 'r2')
result
# Out:
# {'fit_time': array([0.0057795 , 0.00273824, 0.00261497, 0.00263286, 0.00256586]),
#  'score_time': array([0.00291419, 0.0019536 , 0.00195432, 0.00187922, 0.00194669]),
#  'test_score': array([0.76123487, 0.70840689, 0.77720769, 0.73365562, 0.7551376 ]),
#  'train_score': array([0.74737531, 0.75930033, 0.74326474, 0.75468466, 0.74915469])}

# %%
train_acc = result['train_score'].mean() * 100
train_acc
# Out:
# np.float64(75.07559465098191)

# %%
test_acc = result['test_score'].mean() * 100
test_acc
# Out:
# np.float64(74.71285330088385)

# %%
##Other Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
models = []
models.append(("Linear Regression", LinearRegression()))
models.append(("Knn", KNeighborsRegressor()))
models.append(("Decision tree", DecisionTreeRegressor()))
models.append(("Random Forest", RandomForestRegressor()))

for model in models:
  result = cross_validate(model[1],X,Y, cv =5 , return_train_score=True, scoring = 'r2')
  print(model[0])
  train_acc = round(result['train_score'].mean()*100,2)
  test_acc = round(result['test_score'].mean()*100,2)
  print(f" Training Score : {train_acc}")
  print(f" Testing Score : {test_acc}")
# Out:
# Linear Regression
#  Training Score : 75.08
#  Testing Score : 74.71
# Knn
#  Training Score : 81.45
#  Testing Score : 68.86
# Decision tree
#  Training Score : 99.9
#  Testing Score : 70.19
# Random Forest
#  Training Score : 97.65
#  Testing Score : 83.59

# %% [markdown]
# Random Forest has the maxium accuracy
#
# ---

# %% [markdown]
# Tuning MOdel

# %%
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV

# %%
params = {
    'n_estimators': [100,200,300],
    'max_depth': [None,5,10],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,4],
    'bootstrap': [True,False]


}

#bootstrap tells us to use random data/the entire data

random_search = RandomizedSearchCV(

   param_distributions=params,
   estimator=RandomForestRegressor(),
   cv=5,
   return_train_score=True,
   scoring='r2',
   n_jobs=-1

)

# %%
random_search.fit(X,Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 5, 10],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    return_train_score=True, scoring='r2')

# %%
random_search.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_depth': 5,
#  'bootstrap': True}

# %%
random_search.cv_results_['mean_train_score'].mean()*100
# Out:
# np.float64(91.88113382639706)

# %%
random_search.cv_results_['mean_test_score'].mean()*100
# Out:
# np.float64(82.91635266730715)

# %%
RF = RandomForestRegressor(
    n_estimators=300,
    min_samples_split= 2,
 min_samples_leaf= 1,
 max_depth= 5,
 bootstrap= True
)

# %%
RF.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=300)

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import r2_score

# Predict on training data
predicted_train_data = RF.predict(X_train)
train_score = r2_score(y_true=Y_train, y_pred=predicted_train_data)

# Predict on test data
predicted_test_data = RF.predict(X_test)
test_score = r2_score(y_true=Y_test, y_pred=predicted_test_data)

# Print results
print(f"R_squared for training data : {round(train_score * 100, 2)}%")
print(f"R_squared for testing data : {round(test_score * 100, 2)}%")
# Out:
# R_squared for training data : 88.03%
# R_squared for testing data : 90.16%

# %%
#creating a regression line

# %%
sns.regplot(x=Y_train , y = predicted_train_data,
            lowess = True,
            line_kws = {'color': 'red'},
            scatter_kws = {'alpha': 0.25})

plt.title("Y train actual vs y train predicted")
plt.xlabel("Y train actual")
plt.ylabel("Y train predicted")
plt.show()

# %%
sns.regplot(x=Y_test , y = predicted_test_data,
            lowess = True,
            line_kws = {'color': 'red'},
            scatter_kws = {'alpha': 0.25})

plt.title("Y test actual vs y test predicted")
plt.xlabel("Y test actual")
plt.ylabel("Y test predicted")
plt.show()

# %%
X
# Out:
#            age  sex       bmi  children  smoker  region
# 0    -1.440418    0 -0.453160 -0.909234       1       3
# 1    -1.511647    1  0.509422 -0.079442       0       2
# 2    -0.799350    1  0.383155  1.580143       0       2
# 3    -0.443201    1 -1.305052 -0.909234       0       1
# 4    -0.514431    1 -0.292456 -0.909234       0       1
# ...        ...  ...       ...       ...     ...     ...
# 1333  0.767704    1  0.050269  1.580143       0       1
# 1334 -1.511647    0  0.206053 -0.909234       0       0
# 1335 -1.511647    0  1.014490 -0.909234       0       2
# 1336 -1.297958    0 -0.797524 -0.909234       0       3
# 1337  1.551231    0 -0.261299 -0.909234       1       1
#
# [1337 rows x 6 columns]

# %%
#testing model

# %%
age = 24
sex = 1
bmi = 35
children = 3
smoker = 1
region = 3
#in column order

# %%
age1 = std_scaler.fit_transform([[24]])
bmi1 = std_scaler.fit_transform([[35]])
chd1 = std_scaler.fit_transform([[3]])

print(age1)
print(bmi1)
print(chd1)
# Out:
# [[0.]]
# [[0.]]
# [[0.]]

# %%
RF.predict([[age1[0][0],sex,bmi1[0][0],chd1[0][0],smoker,region]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([15570.86821906])

# %%
#Predicted charges are 15553.35

# %%
age = 55
sex = 2
bmi = 41
children = 2
smoker = 1
region = 3
#in column order

# %%
#Test Cse 2

age2 = std_scaler.transform([[55]])
bmi2 = std_scaler.transform([[41]])
chd2 = std_scaler.transform([[2]])

# %%
RF.predict([[age2[0][0],sex,bmi2[0][0],chd2[0][0],smoker,region]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([46113.31380678])

# %%
#Thanks to DFL Lab

# %%
# %whos
# Out:
# Variable                Type                     Data/Info
# ----------------------------------------------------------
# Categorical_columns     list                     n=3
# DecisionTreeRegressor   ABCMeta                  <class 'sklearn.tree._cla<...>s.DecisionTreeRegressor'>
# GridSearchCV            ABCMeta                  <class 'sklearn.model_sel<...>on._search.GridSearchCV'>
# KNeighborsRegressor     ABCMeta                  <class 'sklearn.neighbors<...>ion.KNeighborsRegressor'>
# LabelEncoder            type                     <class 'sklearn.preproces<...>ing._label.LabelEncoder'>
# LinearRegression        ABCMeta                  <class 'sklearn.linear_mo<...>._base.LinearRegression'>
# Numerical_columns       list                     n=4
# RF                      RandomForestRegressor    RandomForestRegressor(max<...>epth=5, n_estimators=300)
# RandomForestRegressor   ABCMeta                  <class 'sklearn.ensemble.<...>t.RandomForestRegressor'>
# ...

# %%
import joblib

joblib.dump(std_scaler, "scaler.pkl")
joblib.dump(lm, "insurance_model.pkl")

print("Saved scaler.pkl and insurance_model.pkl")
# Out:
# Saved scaler.pkl and insurance_model.pkl

# %%
import joblib

# Save the final trained model
joblib.dump(random_search, "insurance_pipeline.pkl")

print("Model saved as insurance_pipeline.pkl")
# Out:
# Model saved as insurance_pipeline.pkl

# %%
import gradio as gr
import joblib
import numpy as np

# Load your pipeline
pipeline = joblib.load("insurance_pipeline.pkl")

def predict_insurance(age, bmi, children, sex, smoker, region):
    input_data = np.array([[age, bmi, children, sex, smoker, region]])
    prediction = pipeline.predict(input_data)[0]
    return f"Estimated Medical Cost: ${prediction:,.2f}"

# UI choices
sex_options = ["female", "male"]
smoker_options = ["no", "yes"]
region_options = ["southeast", "southwest", "northeast", "northwest"]

with gr.Blocks(css="""
    .gradio-container {max-width: 650px; margin: auto;}
    h1 {text-align: center; font-size: 2.2rem; margin-bottom: 10px;}
    .section-title {font-size: 1.1rem; margin-top: 18px; font-weight: 600;}
""") as demo:

    gr.Markdown("# 🩺 PrediMed — Medical Insurance Cost Predictor")

    # personal details
    gr.Markdown("<div class='section-title'>Personal Details</div>")

    age = gr.Slider(18, 70, value=30, label="Age")
    sex = gr.Dropdown(sex_options, label="Sex")

    # health details
    gr.Markdown("<div class='section-title'>Health Details</div>")

    bmi = gr.Slider(15, 45, value=25, label="BMI")
    children = gr.Slider(0, 5, step=1, value=0, label="Number of Children")
    smoker = gr.Dropdown(smoker_options, label="Smoker?")

    # region
    gr.Markdown("<div class='section-title'>Region</div>")

    region = gr.Dropdown(region_options, label="Region")

    # output
    output = gr.Textbox(label="Predicted Insurance Cost")

    gr.Button("Predict Cost").click(
        predict_insurance,
        inputs=[age, bmi, children, sex, smoker, region],
        outputs=output
    )

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9ccf7e6c5f4a457bd1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9ccf7e6c5f4a457bd1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
